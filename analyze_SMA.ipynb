# %% [markdown]
# #### Import Libraries

# %%
import psycopg2
import plotly.graph_objects as go
import plotly.subplots as ms
import plotly.express as px
import pandas as pd
import numpy as np
from array import *

# %% [markdown]
# #### Establish Connection with Database

# %%
connection = psycopg2.connect(database="tickerdb",
                        user='postgres', password='pass123', 
                        host='127.0.0.1', port='5432'
)
  
connection.autocommit = True
cursor = connection.cursor()

# %% [markdown]
# #### Fetch data and insert into variables

# %%
cursor.execute('''select datetime from ticker;''')
date = cursor.fetchall()
cursor.execute('''select close from ticker;''')
close = cursor.fetchall()
cursor.execute('''select high from ticker;''')
high = cursor.fetchall()
cursor.execute('''select low from ticker;''')
low = cursor.fetchall() 
cursor.execute('''select open from ticker;''')
open = cursor.fetchall()
cursor.execute('''select volume from ticker;''')
volume = cursor.fetchall()
connection.close()

# %% [markdown]
# #### Get data ready to pass it to graph function

# %%
date_data = [d[0] for d in date]
close_data = [c[0] for c in close]
high_data = [h[0] for h in high]
low_data = [l[0] for l in low]
open_data = [o[0] for o in open]
volume_data = [v[0] for v in volume]

# %% [markdown]
# #### Initialize graph with 2 halves and plot it

# %%
fig = ms.make_subplots(rows=2,cols=1)

fig.append_trace(go.Candlestick(x=date_data,open=open_data,high=high_data,low=low_data,close=close_data),row=1,col=1)
fig.append_trace(go.Bar(x=date_data,y=volume_data),row=2,col=1)

fig.update(layout_xaxis_rangeslider_visible=False,layout_title = 'HINDALCO',layout_yaxis_title="Stock Price",layout_xaxis_title="Date",layout_plot_bgcolor='#000',layout_height=1000)
    
fig.show()
# Out:
# <div>                            <div id="13ec6cbc-0a7b-4666-8bb4-00d87c7e0c3f" class="plotly-graph-div" style="height:1000px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("13ec6cbc-0a7b-4666-8bb4-00d87c7e0c3f")) {                    Plotly.newPlot(                        "13ec6cbc-0a7b-4666-8bb4-00d87c7e0c3f",                        [{"close":[114.0,111.1,113.8,111.75,108.1,109.55,103.45,102.45,104.25,105.75,106.4,106.8,104.55,103.5,100.2,99.9,98.5,99.3,98.85,97.35,97.65,97.45,98.8,98.4,105.35,105.6,113.6,115.75,120.8,124.55,121.95,117.4,114.75,115.65,115.2,114.85,120.05,119.65,123.5,121.2,121.6,120.75,125.4,125.4,130.9,141.75,138.2,136.0,137.15,137.65,137.35,142.9,142.5,140.7,134.05,135.45,141.45,143.5,144.85,145.15,143.75,141.25,137.2,134.3,131.65,138.9,138.7,135.2,136.75,144.1,143.4,142.2,141.2,138.5,141.2,152.05,156.2,159.7,155.1,152.05,147.1,149.65,147.2,149.3,148.0,150.05,155.2,160.7,169.85,169.25,169.6,169.75,162.65,169.25,162.35,161.2,162.65,166.8,167.75,163.8,165.3,166.8,166.7,165.25,160.9,164.2,175.25,178.25,173.75,173.25,174.5,169.0,170.55,176.25,166.75,173.4,174.7,182.3,188.65,184.6,183.85,188.25,193.75,198.0,191.8,187.8,192.6,191.7,184.3,190.9,195.65,191.75,189.1,183.95,185.65,185.4,180
.0,66.9,63.7,60.9,67.0,64.85,65.8,68.9,69.05,69.5,68.5,66.4,67.15,69.45,68.75,70.25,74.95,79.25,79.4,83.15,81.1,83.8,83.5,84.9,83.9,81.5,81.0,85.2,86.0,87.0,91.3,83.25,84.4,88.0,87.95,86.65,89.1,84.9,88.95,87.3,87.7,92.2,92.0,96.3,97.05,101.8,101.8,101.1,98.4,103.15,101.75,96.9,96.35,98.65,96.9,91.15,90.45,91.9,91.7,89.85,91.6,93.4,89.3,89.8 ...

# %% [markdown]
# ### SMA Strategy:

# %% [markdown]
# #### Calculate two moving averages and plot them on graph:

# %%
close = pd.Series(close_data)
date = pd.Series(date_data)

long = close.rolling(window=50,min_periods=1).mean()
short = close.rolling(window=20,min_periods=1).mean()

fig = px.line()
fig.add_trace(go.Scatter(x=date,y=close,name="Close",line=dict(color="cyan")))
fig.add_trace(go.Scatter(x=date,y=long,name="longMA",line=dict(color="red")))
fig.add_trace(go.Scatter(x=date,y=short,name="shortMA",line=dict(color="green")))
fig.update_layout(title="HINDALCO",yaxis_title="Stock Price",xaxis_title="Date")

fig.show()
# Out:
# <div>                            <div id="c7ce3712-82e8-4adc-9e24-111da5f57806" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c7ce3712-82e8-4adc-9e24-111da5f57806")) {                    Plotly.newPlot(                        "c7ce3712-82e8-4adc-9e24-111da5f57806",                        [{"hovertemplate":"<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"xaxis":"x","yaxis":"y","type":"scatter"},{"line":{"color":"cyan"},"name":"Close","x":["2014-01-24T00:00:00","2014-01-27T00:00:00","2014-01-28T00:00:00","2014-01-29T00:00:00","2014-01-30T00:00:00","2014-01-31T00:00:00","2014-02-03T00:00:00","2014-02-04T00:00:00","2014-02-05T00:00:00","2014-02-06T00:00:00","2014-02-07T00:00:00","2014-02-10T00:00:00","2014-02-11T00:00:00","2014-02-12T00:00:00","2014-02-13T00:00:00","2014-02-14T00:00:00","2014-02-17T00:00:00","2014-02-18T00:00:00","2014-02-19T00:00:00","2014-02-20T00:00:00","2014-02-21T00:00:00","2014-02-24T00:00:00","2014-02-25T00:00:00","2014-02-26T00:00:00","2014-02-28T00:00:00","2014-03-03T00:00:00","2014-03-04T00:00:00","2014-03-05T00:00:00","2014-03-06T00:00:00","2014-03-07T00:00:00","2014-03-10T00:00:00","2014-03-11T00:00:00","2014-03-12T00:00:00","2014-03-13T00:00:00","2014-03-14T00:00:00","2014-03-18T00:00:00","2014-03-19T00:00:00","2014-03-20T00:00:00","2014-03-21T00:00:00","2014-03-22T00:00:00","2014-03-24T00:00:00","2014-03-25T00:00:00","2014-03-26T00:00:00","2014-03-27T00:00:00","2014-03-28T00:00:00","2014-03-31T00:00:00","2014-04-01T00:00:00","2014-04-02T00:00:00","2014-04-03T00:00:00","2014-04-04T00:00:00","2014-04-07T00:00:00","2014-04-09T00:00:00","2014-04-10T00:00:00","2014-04-11T00:00:00","2014-04-15T00:00:00","2014-04-16T00:00:00","2014-04-17T00:00:00","2014-04-21T00:00:00","2014-04-22T00:00:00","2014-04-23T00:00:00","2014-04-25T00:00:00","2014-04-28T00:00:00","2014-04-29T00:00:00","2014-04-30T00:00:00","2014-05-02T00:00:00","2014-05-05T00:00:00","2014-05-06T00:00:00","2014-05-07T00:00:00","2014-05-08T00:00:00","2014-05-09T00:00:00","2014-05-12T00:00:00","2014-05-13T00:00:00","2014-05-14T00:00:00","2014-05-15T00:00:00","2014-05-16T00:00:00","2014-05-19T00:00:00","2014-05-20T00:00:00","2014-05-21T00:00:00","2014-05-22T00:00:00","2014-05-23T00:00:00","2014-05-26T00:00:00","2014-05-27T00:00:00","2014-05-28T00:00:00","2014-05-29T00:00:00","2014-05-30T00:00:00","2014-06-02T00:00:00","2014-06-03T00:00:00","2014-06-04T00:00:00","2014-06-05T00:00:00","2014-06-06T00:00:00","2014-06-09T00:00:00","2014-06-10T00:00:00","2014-06-11T00:00:00","2014-06-12T00:00:00","2014-06-13T00:00:00","2014-06-16T00:00:00","2014-06-17T00:00:00","2014-06-18T00:00:00","2014-06-19T00:00:00","2014-06-20T00:00:00","2014-06-23T00:00:00","2014-06-24T00:00:00","2014-06-25T00:00:00","2014-06-26T00:00:00","2014-06-27T00:00:00","2014-06-30T00:00:00","2014-07-01T00:00:00","2014-07-02T00:00:00","2014-07-03T00:00:00","2014-07-04T00:00:00","2014-07-07T00:00:00","2014-07-08T00:00:00","2014-07-09T00:00:00","2014-07-10T00:00:00","2014-07-11T00:00:00","2014-07-14T00:00:00","2014-07-15T00:00:00","2014-07-16T00:00:00","2014-07-17T00:00:00","2014-07-18T00:00:00","2014-07-21T00:00:00","2014-07-22T00:00:00","2014-07-23T00:00:00","2014-07-24T00:00:00","2014-07-25T00:00:00","2014-07-28T00:00:00","2014-07-30T00:00:00","2014-07-31T00:00:00","2014-08-01T00:00:00","2014-08-04T00:00:00","2014-08-05T00:00:00","2014-08-06T00:00:00","2014-08-07T00:00:00","2014-08-08T00:00:00","2014-08-11T00:00:00","2014-08-12T00:00:00","2014-08-13T00:00:00","2014-08-14T00:00:00","2014-08-18T00:00:00","2014-08-19T00:00:00","2014-08-20T00:00:00","2014-08-21T00:00:00","2014-08-22T00:00:00","2014-08-25T00:00:00","2014-08-26T00:00:00","2014-0 ...

# %% [markdown]
# #### Calculate buy and sell signals

# %%
signal = np.where(short > long,1,0)
signal = pd.Series(signal)

position = signal.diff()
buy = np.where(position == 1,close,np.NAN)
sell = np.where(position == -1,close,np.NAN)

# %% [markdown]
# #### Plot buy and sell signals on graph

# %%
fig = px.line()
fig.add_trace(go.Scatter(x=date,y=close,name="Close Price",line=dict(color="cyan")))
fig.add_trace(go.Scatter(x=date,y=long,name="longMA",line=dict(color="red")))
fig.add_trace(go.Scatter(x=date,y=short,name="shortMA",line=dict(color="green")))
fig.add_trace(go.Scatter(x=date,y=buy,mode="markers",name="buy signal",marker=dict(color="green",size=8,symbol="triangle-up")))
fig.add_trace(go.Scatter(x=date,y=sell,mode="markers",name="sell signal",marker=dict(color="red",size=8,symbol="triangle-down")))
fig.update_layout(title="HINDALCO",yaxis_title="Stock Price",xaxis_title="Date")

fig.show()
# Out:
# <div>                            <div id="d63393bd-bddd-4e99-a597-5b3a3016ceaf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d63393bd-bddd-4e99-a597-5b3a3016ceaf")) {                    Plotly.newPlot(                        "d63393bd-bddd-4e99-a597-5b3a3016ceaf",                        [{"hovertemplate":"<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"xaxis":"x","yaxis":"y","type":"scatter"},{"line":{"color":"cyan"},"name":"Close Price","x":["2014-01-24T00:00:00","2014-01-27T00:00:00","2014-01-28T00:00:00","2014-01-29T00:00:00","2014-01-30T00:00:00","2014-01-31T00:00:00","2014-02-03T00:00:00","2014-02-04T00:00:00","2014-02-05T00:00:00","2014-02-06T00:00:00","2014-02-07T00:00:00","2014-02-10T00:00:00","2014-02-11T00:00:00","2014-02-12T00:00:00","2014-02-13T00:00:00","2014-02-14T00:00:00","2014-02-17T00:00:00","2014-02-18T00:00:00","2014-02-19T00:00:00","2014-02-20T00:00:00","2014-02-21T00:00:00","2014-02-24T00:00:00","2014-02-25T00:00:00","2014-02-26T00:00:00","2014-02-28T00:00:00","2014-03-03T00:00:00","2014-03-04T00:00:00","2014-03-05T00:00:00","2014-03-06T00:00:00","2014-03-07T00:00:00","2014-03-10T00:00:00","2014-03-11T00:00:00","2014-03-12T00:00:00","2014-03-13T00:00:00","2014-03-14T00:00:00","2014-03-18T00:00:00","2014-03-19T00:00:00","2014-03-20T00:00:00","2014-03-21T00:00:00","2014-03-22T00:00:00","2014-03-24T00:00:00","2014-03-25T00:00:00","2014-03-26T00:00:00","2014-03-27T00:00:00","2014-03-28T00:00:00","2014-03-31T00:00:00","2014-04-01T00:00:00","2014-04-02T00:00:00","2014-04-03T00:00:00","2014-04-04T00:00:00","2014-04-07T00:00:00","2014-04-09T00:00:00","2014-04-10T00:00:00","2014-04-11T00:00:00","2014-04-15T00:00:00","2014-04-16T00:00:00","2014-04-17T00:00:00","2014-04-21T00:00:00","2014-04-22T00:00:00","2014-04-23T00:00:00","2014-04-25T00:00:00","2014-04-28T00:00:00","2014-04-29T00:00:00","2014-04-30T00:00:00","2014-05-02T00:00:00","2014-05-05T00:00:00","2014-05-06T00:00:00","2014-05-07T00:00:00","2014-05-08T00:00:00","2014-05-09T00:00:00","2014-05-12T00:00:00","2014-05-13T00:00:00","2014-05-14T00:00:00","2014-05-15T00:00:00","2014-05-16T00:00:00","2014-05-19T00:00:00","2014-05-20T00:00:00","2014-05-21T00:00:00","2014-05-22T00:00:00","2014-05-23T00:00:00","2014-05-26T00:00:00","2014-05-27T00:00:00","2014-05-28T00:00:00","2014-05-29T00:00:00","2014-05-30T00:00:00","2014-06-02T00:00:00","2014-06-03T00:00:00","2014-06-04T00:00:00","2014-06-05T00:00:00","2014-06-06T00:00:00","2014-06-09T00:00:00","2014-06-10T00:00:00","2014-06-11T00:00:00","2014-06-12T00:00:00","2014-06-13T00:00:00","2014-06-16T00:00:00","2014-06-17T00:00:00","2014-06-18T00:00:00","2014-06-19T00:00:00","2014-06-20T00:00:00","2014-06-23T00:00:00","2014-06-24T00:00:00","2014-06-25T00:00:00","2014-06-26T00:00:00","2014-06-27T00:00:00","2014-06-30T00:00:00","2014-07-01T00:00:00","2014-07-02T00:00:00","2014-07-03T00:00:00","2014-07-04T00:00:00","2014-07-07T00:00:00","2014-07-08T00:00:00","2014-07-09T00:00:00","2014-07-10T00:00:00","2014-07-11T00:00:00","2014-07-14T00:00:00","2014-07-15T00:00:00","2014-07-16T00:00:00","2014-07-17T00:00:00","2014-07-18T00:00:00","2014-07-21T00:00:00","2014-07-22T00:00:00","2014-07-23T00:00:00","2014-07-24T00:00:00","2014-07-25T00:00:00","2014-07-28T00:00:00","2014-07-30T00:00:00","2014-07-31T00:00:00","2014-08-01T00:00:00","2014-08-04T00:00:00","2014-08-05T00:00:00","2014-08-06T00:00:00","2014-08-07T00:00:00","2014-08-08T00:00:00","2014-08-11T00:00:00","2014-08-12T00:00:00","2014-08-13T00:00:00","2014-08-14T00:00:00","2014-08-18T00:00:00","2014-08-19T00:00:00","2014-08-20T00:00:00","2014-08-21T00:00:00","2014-08-22T00:00:00","2014-08-25T00:00:00","2014-08-26T00:00:00"," ...

# %% [markdown]
# #### Calculate and print Total Profit

# %%
buy_price = np.where(position == 1,close,0)
total_buy_price= sum(tt_buy,1216)

sell_price = np.where(position == -1,close,0)
total_sell_price = sum(tt_sell,1216)

#Profit = selling price - cost price
total_profit = total_sell_price - total_buy_price
print(f"Total Profit = {total_profit}")
# Out:
# Total Profit = 20.20
